# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# using colab secrets to store our passwords and keys
#from google.colab import userdata

# %% [markdown]
# # Making the API call and viewing the json

# %%
#api_key = userdata.get('aeroBoxDataApi')
icao = "EDDB"
date = datetime.now().date()
time_1 = "00:00"
time_2 = "11:59"

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{date}T{time_1}/{date}T{time_2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4" #api_key
    }

response = requests.request("GET",
                            url,
                            headers = headers,
                            params = querystring)

flights_json = response.json()

flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha'},
#     'scheduledTime': {'utc': '2024-03-10 23:35Z',
#      'local': '2024-03-11 02:35+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 05:50Z',
#      'local': '2024-03-11 06:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:57Z',
#      'local': '2024-03-11 06:57+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:02Z',
#      'local': '2024-03-11 07:02+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'callSign': 'QTR7R',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTime': {'utc': '2024-03-11 05:10Z',
#      'local': '2024-03-11 06:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:12Z',
#      'local': '2024-03-11 06:12+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:13Z',
#      'local': '2024-03-11 06:13+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '37',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:40Z',
#      'local': '2024-03-11 07:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:16Z',
#      'local': '2024-03-11 07:16+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1185',
#    'callSign': 'EZS28LM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-AYE',
#     'modeS': '4B0274',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTime': {'utc': '2024-03-11 05:10Z',
#      'local': '2024-03-11 06:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:12Z',
#      'local': '2024-03-11 06:12+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:13Z',
#      'local': '2024-03-11 06:13+01:00'},
#     'checkInDesk': '42-50',
#     'gate': '37',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:40Z',
#      'local': '2024-03-11 07:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:16Z',
#      'local': '2024-03-11 07:16+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1185',
#    'callSign': 'EZS28LM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-AYE',
#     'modeS': '4B0274',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark'},
#     'scheduledTime': {'utc': '2024-03-10 22:50Z',
#      'local': '2024-03-10 18:50-04:00'},
#     'revisedTime': {'utc': '2024-03-10 23:14Z',
#      'local': '2024-03-10 19:14-04:00'},
#     'runwayTime': {'utc': '2024-03-10 23:14Z',
#      'local': '2024-03-10 19:14-04:00'},
#     'terminal': 'C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:37Z',
#      'local': '2024-03-11 07:37+01:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'callSign': 'UAL962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N66051', 'modeS': 'A8B75A', 'model': 'Boeing 767-400'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-11 05:45Z',
#      'local': '2024-03-11 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:54Z',
#      'local': '2024-03-11 06:54+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:54Z',
#      'local': '2024-03-11 06:54+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:43Z',
#      'local': '2024-03-11 07:43+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 12',
#    'callSign': 'EWG655',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABHG', 'modeS': '3C4907', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#     'scheduledTime': {'utc': '2024-03-11 05:35Z',
#      'local': '2024-03-11 06:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:38Z',
#      'local': '2024-03-11 06:38+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:38Z',
#      'local': '2024-03-11 06:38+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:46Z',
#      'local': '2024-03-11 07:46+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3312',
#    'callSign': 'RYR59MW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QCR', 'modeS': '4D2248', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-11 05:30Z',
#      'local': '2024-03-11 06:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:49Z',
#      'local': '2024-03-11 07:49+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 121',
#    'callSign': 'DTR2PV',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 05:45Z',
#      'local': '2024-03-11 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:45Z',
#      'local': '2024-03-11 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:51Z',
#      'local': '2024-03-11 07:51+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINB',
#     'modeS': '3C65C2',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LATI', 'iata': 'TIA', 'name': 'Tirana'},
#     'scheduledTime': {'utc': '2024-03-11 05:00Z',
#      'local': '2024-03-11 06:00+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#      'local': '2024-03-11 08:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'W4 6611',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LXN', 'modeS': '471F6F', 'model': 'Airbus A321'},
#    'airline': {'name': 'Aero Services Executive',
#     'iata': 'W4',
#     'icao': 'WMT'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 06:00Z',
#      'local': '2024-03-11 07:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:00Z',
#      'local': '2024-03-11 07:00+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:15Z',
#      'local': '2024-03-11 07:15+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:57Z',
#      'local': '2024-03-11 07:57+01:00'},
#     'terminal': '1',
#     'gate': 'A01',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1928',
#    'callSign': 'DLH7N',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIEI',
#     'modeS': '3C64A9',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-11 06:00Z',
#      'local': '2024-03-11 07:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:00Z',
#      'local': '2024-03-11 07:00+01:00'},
#     'terminal': '1',
#     'gate': '116',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:59Z',
#      'local': '2024-03-11 07:59+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2002',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:59Z',
#      'local': '2024-03-11 07:59+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5385',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-11 05:45Z',
#      'local': '2024-03-11 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:47Z',
#      'local': '2024-03-11 06:47+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:07Z',
#      'local': '2024-03-11 07:07+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '161,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:02Z',
#      'local': '2024-03-11 08:02+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9048',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-11 05:05Z',
#      'local': '2024-03-11 07:05+02:00'},
#     'revisedTime': {'utc': '2024-03-11 05:08Z',
#      'local': '2024-03-11 07:08+02:00'},
#     'runwayTime': {'utc': '2024-03-11 05:22Z',
#      'local': '2024-03-11 07:22+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '34',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 08:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:03Z',
#      'local': '2024-03-11 08:03+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:09Z',
#      'local': '2024-03-11 08:09+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKP', 'modeS': '461E1F', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 52FP',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 04:50Z',
#      'local': '2024-03-11 05:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 04:42Z',
#      'local': '2024-03-11 05:42+01:00'},
#     'runwayTime': {'utc': '2024-03-11 04:57Z',
#      'local': '2024-03-11 05:57+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '002-007',
#     'gate': 'C72',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:35Z',
#      'local': '2024-03-11 08:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:06Z',
#      'local': '2024-03-11 08:06+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:07Z',
#      'local': '2024-03-11 08:07+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 111',
#    'callSign': 'RYR81QP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EBC', 'modeS': '4CA700', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'terminal': 'C',
#     'gate': 'C4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:08Z',
#      'local': '2024-03-11 08:08+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 3219',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSK',
#     'modeS': '502CE5',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'terminal': 'C',
#     'gate': 'C4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:08Z',
#      'local': '2024-03-11 08:08+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BT 211',
#    'callSign': 'BTI74A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSK',
#     'modeS': '502CE5',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#   {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#     'scheduledTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-03-11 05:15Z',
#      'local': '2024-03-11 07:15+02:00'},
#     'terminal': 'C',
#     'gate': 'C4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:08Z',
#      'local': '2024-03-11 08:08+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:46Z',
#      'local': '2024-03-11 08:46+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'JU 7659',
#    'callSign': 'ASL86U',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-CSK',
#     'modeS': '502CE5',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#   {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#      'local': '2024-03-11 08:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'scheduledTime': {'utc': '2024-03-11 05:50Z',
#      'local': '2024-03-11 06:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:57Z',
#      'local': '2024-03-11 06:57+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:57Z',
#      'local': '2024-03-11 06:57+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#      'local': '2024-03-11 08:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-11 06:10Z',
#      'local': '2024-03-11 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:22Z',
#      'local': '2024-03-11 07:22+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:23Z',
#      'local': '2024-03-11 07:23+01:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F31',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:14Z',
#      'local': '2024-03-11 08:14+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA223',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LZD', 'modeS': '440605', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:16Z',
#      'local': '2024-03-11 08:16+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4873',
#    'callSign': 'EJU40FD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICK', 'modeS': '440053', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 05:40Z',
#      'local': '2024-03-11 06:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:44Z',
#      'local': '2024-03-11 06:44+01:00'},
#     'runwayTime': {'utc': '2024-03-11 05:44Z',
#      'local': '2024-03-11 06:44+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:16Z',
#      'local': '2024-03-11 08:16+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4873',
#    'callSign': 'EJU40FD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICK', 'modeS': '440053', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LOWG', 'iata': 'GRZ', 'name': 'Graz'},
#     'scheduledTime': {'utc': '2024-03-11 06:30Z',
#      'local': '2024-03-11 07:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:28Z',
#      'local': '2024-03-11 07:28+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:28Z',
#      'local': '2024-03-11 07:28+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:40Z',
#      'local': '2024-03-11 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:26Z',
#      'local': '2024-03-11 08:26+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8347',
#    'callSign': 'EWG2KA',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EUW', 'modeS': '4D240E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LOWG', 'iata': 'GRZ', 'name': 'Graz'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:40Z',
#      'local': '2024-03-11 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:26Z',
#      'local': '2024-03-11 08:26+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 8833',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EUW', 'modeS': '4D240E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LYBE',
#      'iata': 'BEG',
#      'name': 'Belgrade'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:00Z',
#      'local': '2024-03-11 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:40Z',
#      'local': '2024-03-11 08:40+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'JA 350',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LY-LOC', 'modeS': '503CC0', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-11 06:45Z',
#      'local': '2024-03-11 07:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:45Z',
#      'local': '2024-03-11 07:45+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:04Z',
#      'local': '2024-03-11 08:04+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:55Z',
#      'local': '2024-03-11 08:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:48Z',
#      'local': '2024-03-11 08:48+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH7EE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZZ',
#     'modeS': '3C675A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-11 06:20Z',
#      'local': '2024-03-11 07:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:26Z',
#      'local': '2024-03-11 07:26+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:49Z',
#      'local': '2024-03-11 07:49+01:00'},
#     'checkInDesk': '1',
#     'gate': 'B38',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:45Z',
#      'local': '2024-03-11 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:49Z',
#      'local': '2024-03-11 08:49+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YL-AAX',
#     'modeS': '502D28',
#     'model': 'Airbus A220-300'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 08:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 08:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:10Z',
#      'local': '2024-03-11 09:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:52Z',
#      'local': '2024-03-11 08:52+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1930',
#    'callSign': 'DLH2X',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTime': {'utc': '2024-03-11 06:30Z',
#      'local': '2024-03-11 07:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:26Z',
#      'local': '2024-03-11 07:26+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:39Z',
#      'local': '2024-03-11 07:39+01:00'},
#     'checkInDesk': '123',
#     'gate': 'D11',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:05Z',
#      'local': '2024-03-11 09:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:58Z',
#      'local': '2024-03-11 08:58+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1102',
#    'callSign': 'NOZ2XM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-NII', 'modeS': '47945C', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 06:25Z',
#      'local': '2024-03-11 07:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:50Z',
#      'local': '2024-03-11 07:50+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:50Z',
#      'local': '2024-03-11 07:50+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:03Z',
#      'local': '2024-03-11 09:03+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR1434',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HEPG', 'modeS': '3991E6', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-11 06:55Z',
#      'local': '2024-03-11 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:01Z',
#      'local': '2024-03-11 08:01+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:03Z',
#      'local': '2024-03-11 08:03+01:00'},
#     'checkInDesk': '08',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:07Z',
#      'local': '2024-03-11 09:07+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 163',
#    'callSign': 'RYR11EH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUN', 'modeS': '4D234D', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg'},
#     'scheduledTime': {'utc': '2024-03-11 05:45Z',
#      'local': '2024-03-11 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 06:39Z',
#      'local': '2024-03-11 07:39+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:48Z',
#      'local': '2024-03-11 07:48+01:00'},
#     'terminal': 'A',
#     'gate': 'B02',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:10Z',
#      'local': '2024-03-11 09:10+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9471',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LQB',
#     'modeS': '4D00D6',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:16Z',
#      'local': '2024-03-11 09:16+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'UAG 27G',
#    'callSign': 'UAG27G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'airline': {'name': 'UAG'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-11 05:55Z',
#      'local': '2024-03-11 06:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 05:49Z',
#      'local': '2024-03-11 06:49+01:00'},
#     'runwayTime': {'utc': '2024-03-11 06:03Z',
#      'local': '2024-03-11 07:03+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '046-050',
#     'gate': 'C54',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:40Z',
#      'local': '2024-03-11 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:17Z',
#      'local': '2024-03-11 09:17+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:22Z',
#      'local': '2024-03-11 09:22+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 6892',
#    'callSign': 'EWG27ZJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EXW', 'modeS': '4D2412', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:10Z',
#      'local': '2024-03-11 08:10+01:00'},
#     'terminal': 'erminal3',
#     'gate': 'A12',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:24Z',
#      'local': '2024-03-11 09:24+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8227',
#    'callSign': 'EWG42XB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5321',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'scheduledTime': {'utc': '2024-03-11 04:00Z',
#      'local': '2024-03-11 06:00+02:00'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:22Z',
#      'local': '2024-03-11 09:22+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LY 2371',
#    'callSign': 'ELY2371',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4X-EKB', 'modeS': '738064', 'model': 'Boeing 737'},
#    'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-11 07:05Z',
#      'local': '2024-03-11 08:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:03Z',
#      'local': '2024-03-11 08:03+01:00'},
#     'runwayTime': {'utc': '2024-03-11 07:25Z',
#      'local': '2024-03-11 08:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'B31',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 09:25+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1821',
#    'callSign': 'KLM69H',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-EXH', 'modeS': '4852F5', 'model': 'Embraer 175'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-11 05:50Z',
#      'local': '2024-03-11 08:50+03:00'},
#     'revisedTime': {'utc': '2024-03-11 05:50Z',
#      'local': '2024-03-11 08:50+03:00'},
#     'checkInDesk': 'E-F',
#     'gate': 'F18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:27Z',
#      'local': '2024-03-11 09:27+01:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1721',
#    'callSign': 'THY8VN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-LOB', 'modeS': '4BB1E2', 'model': 'Airbus A330'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-11 06:20Z',
#      'local': '2024-03-11 06:20+00:00'},
#     'revisedTime': {'utc': '2024-03-11 06:20Z',
#      'local': '2024-03-11 06:20+00:00'},
#     'runwayTime': {'utc': '2024-03-11 06:34Z',
#      'local': '2024-03-11 06:34+00:00'},
#     'terminal': '2',
#     'checkInDesk': '29-56',
#     'gate': '418',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:40Z',
#      'local': '2024-03-11 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:30Z',
#      'local': '2024-03-11 09:30+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EI 332',
#    'callSign': 'EIN3JE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-GAL', 'modeS': '4CA836', 'model': 'Airbus A320'},
#    'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#   {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-11 06:20Z',
#      'local': '2024-03-11 06:20+00:00'},
#     'revisedTime': {'utc': '2024-03-11 06:20Z',
#      'local': '2024-03-11 06:20+00:00'},
#     'runwayTime': {'utc': '2024-03-11 06:37Z',
#      'local': '2024-03-11 06:37+00:00'},
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '104',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'callSign': 'RYR23SD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EXE', 'modeS': '4CAA60', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 07:50Z',
#      'local': '2024-03-11 08:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:50Z',
#      'local': '2024-03-11 08:50+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:01Z',
#      'local': '2024-03-11 09:01+01:00'},
#     'terminal': 'erminal2',
#     'gate': 'F7',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:43Z',
#      'local': '2024-03-11 09:43+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5262',
#    'callSign': 'EJU5191',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 07:50Z',
#      'local': '2024-03-11 08:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:50Z',
#      'local': '2024-03-11 08:50+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:01Z',
#      'local': '2024-03-11 09:01+01:00'},
#     'terminal': 'erminal2',
#     'gate': 'F7',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:43Z',
#      'local': '2024-03-11 09:43+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5262',
#    'callSign': 'EJU5191',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'scheduledTime': {'utc': '2024-03-11 06:50Z',
#      'local': '2024-03-11 06:50+00:00'},
#     'revisedTime': {'utc': '2024-03-11 06:49Z',
#      'local': '2024-03-11 06:49+00:00'},
#     'runwayTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 07:00+00:00'},
#     'terminal': '1',
#     'gate': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:50Z',
#      'local': '2024-03-11 09:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2199',
#    'callSign': 'EZY73FB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-UZHO', 'modeS': '40756D', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-11 07:45Z',
#      'local': '2024-03-11 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 07:45Z',
#      'local': '2024-03-11 08:45+01:00'},
#     'terminal': '1',
#     'gate': '140',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:48Z',
#      'local': '2024-03-11 09:48+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:48Z',
#      'local': '2024-03-11 09:48+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5392',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 07:00+00:00'},
#     'revisedTime': {'utc': '2024-03-11 07:00Z',
#      'local': '2024-03-11 07:00+00:00'},
#     'runwayTime': {'utc': '2024-03-11 07:20Z',
#      'local': '2024-03-11 07:20+00:00'},
#     'checkInDesk': '55-61',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:50Z',
#      'local': '2024-03-11 09:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:51Z',
#      'local': '2024-03-11 09:51+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:57Z',
#      'local': '2024-03-11 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2601',
#    'callSign': 'EZY13PJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-UZHK',
#     'modeS': '40756A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 07:15Z',
#      'local': '2024-03-11 07:15+00:00'},
#     'revisedTime': {'utc': '2024-03-11 07:19Z',
#      'local': '2024-03-11 07:19+00:00'},
#     'runwayTime': {'utc': '2024-03-11 07:20Z',
#      'local': '2024-03-11 07:20+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 09:10Z',
#      'local': '2024-03-11 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:53Z',
#      'local': '2024-03-11 09:53+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 990',
#    'callSign': 'BAW990',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUPG', 'modeS': '400877', 'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 8001',
#    'callSign': 'GWI8001',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'airport': {'icao': 'LFST',
#      'iata': 'SXB',
#      'name': 'Strasbourg'},
#     'scheduledTime': {'utc': '2024-03-11 07:55Z',
#      'local': '2024-03-11 08:55+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 09:25Z',
#      'local': '2024-03-11 10:25+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:55Z',
#      'local': '2024-03-11 09:55+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'V7 2596',
#    'callSign': 'VOE2596',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NPB', 'modeS': '346649', 'model': 'Airbus A320'},
#    'airline': {'name': 'Volotea', 'iata': 'V7', 'icao': 'VOE'}},
#   {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-11 07:55Z',
#      'local': '2024-03-11 08:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:57Z',
#      'local': '2024-03-11 09:57+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8059',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
# ...
#     'scheduledTime': {'utc': '2024-03-11 05:25Z',
#      'local': '2024-03-11 07:25+02:00'},
#     'revisedTime': {'utc': '2024-03-11 07:44Z',
#      'local': '2024-03-11 09:44+02:00'},
#     'terminal': 'I',
#     'checkInDesk': '9----13',
#     'gate': 'A01',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#      'local': '2024-03-11 09:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:59Z',
#      'local': '2024-03-11 10:59+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TV 720',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Tibet', 'iata': 'TV', 'icao': 'TBA'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:51Z',
#      'local': '2024-03-11 09:51+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:04Z',
#      'local': '2024-03-11 10:04+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'C11',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:03Z',
#      'local': '2024-03-11 11:03+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:09Z',
#      'local': '2024-03-11 11:09+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1823',
#    'callSign': 'KLM95E',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTime': {'utc': '2024-03-11 06:45Z',
#      'local': '2024-03-11 09:45+03:00'},
#     'revisedTime': {'utc': '2024-03-11 06:45Z',
#      'local': '2024-03-11 09:45+03:00'},
#     'terminal': '1',
#     'checkInDesk': '146-148',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#      'local': '2024-03-11 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:06Z',
#      'local': '2024-03-11 11:06+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:12Z',
#      'local': '2024-03-11 11:12+01:00'},
#     'terminal': '1',
#     'gate': 'X19',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5007',
#    'callSign': 'PGT99EZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NCF',
#     'modeS': '4BB866',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#     'scheduledTime': {'utc': '2024-03-11 07:46Z',
#      'local': '2024-03-11 09:46+02:00'},
#     'revisedTime': {'utc': '2024-03-11 07:46Z',
#      'local': '2024-03-11 09:46+02:00'},
#     'runwayTime': {'utc': '2024-03-11 07:46Z',
#      'local': '2024-03-11 09:46+02:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'TR 720',
#    'callSign': 'TGW720',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#    'airline': {'name': 'Scoot', 'iata': 'TR', 'icao': 'TGW'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-11 08:40Z',
#      'local': '2024-03-11 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:00Z',
#      'local': '2024-03-11 10:00+01:00'},
#     'checkInDesk': '05',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:10Z',
#      'local': '2024-03-11 11:10+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2581',
#    'callSign': 'BEL8CE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-11 08:25Z',
#      'local': '2024-03-11 08:25+00:00'},
#     'revisedTime': {'utc': '2024-03-11 08:32Z',
#      'local': '2024-03-11 08:32+00:00'},
#     'runwayTime': {'utc': '2024-03-11 08:38Z',
#      'local': '2024-03-11 08:38+00:00'},
#     'gate': '8',
#     'runway': '27',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#      'local': '2024-03-11 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:13Z',
#      'local': '2024-03-11 11:13+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8491',
#    'callSign': 'CFE76JZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYT', 'modeS': '406B6D', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:26Z',
#      'local': '2024-03-11 11:26+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5144',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'scheduledTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'runwayTime': {'utc': '2024-03-11 08:54Z',
#      'local': '2024-03-11 09:54+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:26Z',
#      'local': '2024-03-11 11:26+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5144',
#    'callSign': 'EJU70ZR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:05Z',
#      'local': '2024-03-11 10:05+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:12Z',
#      'local': '2024-03-11 10:12+01:00'},
#     'terminal': '5',
#     'checkInDesk': '18-0',
#     'gate': 'D12',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:31Z',
#      'local': '2024-03-11 11:31+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 4505',
#    'callSign': 'NSZ4505',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RXB', 'modeS': '4ACB02', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'departure': {'airport': {'icao': 'ORER', 'iata': 'EBL', 'name': 'Arbil'},
#     'scheduledTime': {'utc': '2024-03-11 06:00Z',
#      'local': '2024-03-11 09:00+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:30Z',
#      'local': '2024-03-11 11:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:35Z',
#      'local': '2024-03-11 11:35+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:42Z',
#      'local': '2024-03-11 11:42+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'UD 445',
#    'callSign': 'UBD445',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LZ-BHM', 'modeS': '452087', 'model': 'Airbus A320'},
#    'airline': {'name': 'UR', 'iata': 'UD', 'icao': 'UBD'}},
#   {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:19Z',
#      'local': '2024-03-11 10:19+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:22Z',
#      'local': '2024-03-11 10:22+01:00'},
#     'checkInDesk': '1-17',
#     'gate': 'A1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#      'local': '2024-03-11 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:39Z',
#      'local': '2024-03-11 11:39+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:45Z',
#      'local': '2024-03-11 11:45+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5182',
#    'callSign': 'EJU39TE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTime': {'utc': '2024-03-11 08:35Z',
#      'local': '2024-03-11 09:35+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:19Z',
#      'local': '2024-03-11 10:19+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:22Z',
#      'local': '2024-03-11 10:22+01:00'},
#     'terminal': '1',
#     'checkInDesk': '1-17',
#     'gate': 'A1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#      'local': '2024-03-11 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:39Z',
#      'local': '2024-03-11 11:39+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:45Z',
#      'local': '2024-03-11 11:45+01:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5182',
#    'callSign': 'EJU39TE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-11 10:00Z',
#      'local': '2024-03-11 11:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:00Z',
#      'local': '2024-03-11 11:00+01:00'},
#     'terminal': 'erminal2',
#     'gate': 'A8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 11:00Z',
#      'local': '2024-03-11 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:43Z',
#      'local': '2024-03-11 11:43+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:44Z',
#      'local': '2024-03-11 11:44+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 3302',
#    'callSign': 'NSZ3302',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-NIG', 'modeS': '4794F2', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-11 08:45Z',
#      'local': '2024-03-11 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:28Z',
#      'local': '2024-03-11 10:28+01:00'},
#     'runwayTime': {'utc': '2024-03-11 09:28Z',
#      'local': '2024-03-11 10:28+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:30Z',
#      'local': '2024-03-11 11:30+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:47Z',
#      'local': '2024-03-11 11:47+01:00'},
#     'terminal': '1',
#     'gate': 'A06',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1734',
#    'callSign': 'AFR69NH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAK', 'modeS': '394C0A', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-11 09:50Z',
#      'local': '2024-03-11 10:50+01:00'},
#     'revisedTime': {'utc': '2024-03-11 09:50Z',
#      'local': '2024-03-11 10:50+01:00'},
#     'runwayTime': {'utc': '2024-03-11 10:07Z',
#      'local': '2024-03-11 11:07+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 11:00Z',
#      'local': '2024-03-11 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:51Z',
#      'local': '2024-03-11 11:51+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 2206',
#    'callSign': 'DLH4X',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBQ', 'modeS': '3C6451', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LOWS',
#      'iata': 'SZG',
#      'name': 'Salzburg'},
#     'scheduledTime': {'utc': '2024-03-11 09:35Z',
#      'local': '2024-03-11 10:35+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:53Z',
#      'local': '2024-03-11 11:53+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4342',
#    'callSign': 'EWG8WT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWH',
#     'modeS': '4D2418',
#     'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LOWS',
#      'iata': 'SZG',
#      'name': 'Salzburg'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#      'local': '2024-03-11 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-11 10:53Z',
#      'local': '2024-03-11 11:53+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 8721',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWH', 'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}}]}

# %% [markdown]
# # Exploring the json

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'},
#    'scheduledTime': {'utc': '2024-03-10 23:35Z',
#     'local': '2024-03-11 02:35+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 05:50Z',
#     'local': '2024-03-11 06:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:57Z',
#     'local': '2024-03-11 06:57+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:02Z',
#     'local': '2024-03-11 07:02+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'callSign': 'QTR7R',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse'},
#    'scheduledTime': {'utc': '2024-03-11 05:10Z',
#     'local': '2024-03-11 06:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:12Z',
#     'local': '2024-03-11 06:12+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:13Z',
#     'local': '2024-03-11 06:13+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '37',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:40Z',
#     'local': '2024-03-11 07:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:16Z',
#     'local': '2024-03-11 07:16+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'DS 1185',
#   'callSign': 'EZS28LM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-AYE', 'modeS': '4B0274', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse'},
#    'scheduledTime': {'utc': '2024-03-11 05:10Z',
#     'local': '2024-03-11 06:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:12Z',
#     'local': '2024-03-11 06:12+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:13Z',
#     'local': '2024-03-11 06:13+01:00'},
#    'checkInDesk': '42-50',
#    'gate': '37',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:40Z',
#     'local': '2024-03-11 07:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:16Z',
#     'local': '2024-03-11 07:16+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 1185',
#   'callSign': 'EZS28LM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-AYE', 'modeS': '4B0274', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark'},
#    'scheduledTime': {'utc': '2024-03-10 22:50Z',
#     'local': '2024-03-10 18:50-04:00'},
#    'revisedTime': {'utc': '2024-03-10 23:14Z',
#     'local': '2024-03-10 19:14-04:00'},
#    'runwayTime': {'utc': '2024-03-10 23:14Z',
#     'local': '2024-03-10 19:14-04:00'},
#    'terminal': 'C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:37Z',
#     'local': '2024-03-11 07:37+01:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'callSign': 'UAL962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N66051', 'modeS': 'A8B75A', 'model': 'Boeing 767-400'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#    'scheduledTime': {'utc': '2024-03-11 05:45Z',
#     'local': '2024-03-11 06:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:54Z',
#     'local': '2024-03-11 06:54+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:54Z',
#     'local': '2024-03-11 06:54+01:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:43Z',
#     'local': '2024-03-11 07:43+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 12',
#   'callSign': 'EWG655',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABHG', 'modeS': '3C4907', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#    'scheduledTime': {'utc': '2024-03-11 05:35Z',
#     'local': '2024-03-11 06:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:38Z',
#     'local': '2024-03-11 06:38+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:38Z',
#     'local': '2024-03-11 06:38+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#     'local': '2024-03-11 08:15+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:46Z',
#     'local': '2024-03-11 07:46+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3312',
#   'callSign': 'RYR59MW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QCR', 'modeS': '4D2248', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken'},
#    'scheduledTime': {'utc': '2024-03-11 05:30Z',
#     'local': '2024-03-11 06:30+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:05Z',
#     'local': '2024-03-11 08:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:49Z',
#     'local': '2024-03-11 07:49+01:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'DX 121',
#   'callSign': 'DTR2PV',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#   'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main'},
#    'scheduledTime': {'utc': '2024-03-11 05:45Z',
#     'local': '2024-03-11 06:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:45Z',
#     'local': '2024-03-11 06:45+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-488',
#    'gate': 'A16',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:51Z',
#     'local': '2024-03-11 07:51+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AINB',
#    'modeS': '3C65C2',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LATI', 'iata': 'TIA', 'name': 'Tirana'},
#    'scheduledTime': {'utc': '2024-03-11 05:00Z',
#     'local': '2024-03-11 06:00+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#     'local': '2024-03-11 08:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'terminal': '2',
#    'gate': 'Z44',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'W4 6611',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HA-LXN', 'modeS': '471F6F', 'model': 'Airbus A321'},
#   'airline': {'name': 'Aero Services Executive', 'iata': 'W4', 'icao': 'WMT'}},
#  {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#    'scheduledTime': {'utc': '2024-03-11 06:00Z',
#     'local': '2024-03-11 07:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:00Z',
#     'local': '2024-03-11 07:00+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:15Z',
#     'local': '2024-03-11 07:15+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:10Z',
#     'local': '2024-03-11 08:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:57Z',
#     'local': '2024-03-11 07:57+01:00'},
#    'terminal': '1',
#    'gate': 'A01',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1928',
#   'callSign': 'DLH7N',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIEI', 'modeS': '3C64A9', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart'},
#    'scheduledTime': {'utc': '2024-03-11 06:00Z',
#     'local': '2024-03-11 07:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:00Z',
#     'local': '2024-03-11 07:00+01:00'},
#    'terminal': '1',
#    'gate': '116',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#     'local': '2024-03-11 08:15+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:59Z',
#     'local': '2024-03-11 07:59+01:00'},
#    'terminal': '1',
#    'gate': 'A03',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2002',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#     'local': '2024-03-11 08:15+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:59Z',
#     'local': '2024-03-11 07:59+01:00'},
#    'terminal': '1',
#    'gate': 'A03',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5385',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABGN', 'modeS': '3C48EE', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Duesseldorf'},
#    'scheduledTime': {'utc': '2024-03-11 05:45Z',
#     'local': '2024-03-11 06:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:47Z',
#     'local': '2024-03-11 06:47+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:07Z',
#     'local': '2024-03-11 07:07+01:00'},
#    'terminal': 'B',
#    'checkInDesk': '161,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:02Z',
#     'local': '2024-03-11 08:02+01:00'},
#    'terminal': '1',
#    'gate': 'A02',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 9048',
#   'callSign': 'GWI52FP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#    'scheduledTime': {'utc': '2024-03-11 05:05Z',
#     'local': '2024-03-11 07:05+02:00'},
#    'revisedTime': {'utc': '2024-03-11 05:08Z',
#     'local': '2024-03-11 07:08+02:00'},
#    'runwayTime': {'utc': '2024-03-11 05:22Z',
#     'local': '2024-03-11 07:22+02:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '34',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 08:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:03Z',
#     'local': '2024-03-11 08:03+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:09Z',
#     'local': '2024-03-11 08:09+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1431',
#   'callSign': 'FIN3AW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LKP', 'modeS': '461E1F', 'model': 'Embraer 190'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Duesseldorf'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:05Z',
#     'local': '2024-03-11 08:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:05Z',
#     'local': '2024-03-11 08:05+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:05Z',
#     'local': '2024-03-11 08:05+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': '4U 52FP',
#   'callSign': 'GWI52FP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWE', 'modeS': '3C5EE5', 'model': 'Airbus A319'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'icao': 'LEPA',
#     'iata': 'PMI',
#     'name': 'Palma De Mallorca'},
#    'scheduledTime': {'utc': '2024-03-11 04:50Z',
#     'local': '2024-03-11 05:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 04:42Z',
#     'local': '2024-03-11 05:42+01:00'},
#    'runwayTime': {'utc': '2024-03-11 04:57Z',
#     'local': '2024-03-11 05:57+01:00'},
#    'terminal': 'N',
#    'checkInDesk': '002-007',
#    'gate': 'C72',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:35Z',
#     'local': '2024-03-11 08:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:06Z',
#     'local': '2024-03-11 08:06+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:07Z',
#     'local': '2024-03-11 08:07+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 111',
#   'callSign': 'RYR81QP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EBC', 'modeS': '4CA700', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#    'scheduledTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'terminal': 'C',
#    'gate': 'C4',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:08Z',
#     'local': '2024-03-11 08:08+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'A3 3219',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSK', 'modeS': '502CE5', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#  {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#    'scheduledTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'terminal': 'C',
#    'gate': 'C4',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:08Z',
#     'local': '2024-03-11 08:08+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BT 211',
#   'callSign': 'BTI74A',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSK', 'modeS': '502CE5', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'airBaltic', 'iata': 'BT', 'icao': 'BTI'}},
#  {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'},
#    'scheduledTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-03-11 05:15Z',
#     'local': '2024-03-11 07:15+02:00'},
#    'terminal': 'C',
#    'gate': 'C4',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:08Z',
#     'local': '2024-03-11 08:08+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:46Z',
#     'local': '2024-03-11 08:46+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'JU 7659',
#   'callSign': 'ASL86U',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-CSK', 'modeS': '502CE5', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}},
#  {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#     'local': '2024-03-11 08:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:10Z',
#     'local': '2024-03-11 08:10+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5068',
#   'callSign': 'EJU5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#    'scheduledTime': {'utc': '2024-03-11 05:50Z',
#     'local': '2024-03-11 06:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:57Z',
#     'local': '2024-03-11 06:57+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:57Z',
#     'local': '2024-03-11 06:57+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:30Z',
#     'local': '2024-03-11 08:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:10Z',
#     'local': '2024-03-11 08:10+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5068',
#   'callSign': 'EJU5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#    'scheduledTime': {'utc': '2024-03-11 06:10Z',
#     'local': '2024-03-11 07:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:22Z',
#     'local': '2024-03-11 07:22+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:23Z',
#     'local': '2024-03-11 07:23+01:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F31',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#     'local': '2024-03-11 08:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:14Z',
#     'local': '2024-03-11 08:14+01:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 223',
#   'callSign': 'AUA223',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LZD', 'modeS': '440605', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#     'local': '2024-03-11 08:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:16Z',
#     'local': '2024-03-11 08:16+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4873',
#   'callSign': 'EJU40FD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICK', 'modeS': '440053', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#    'scheduledTime': {'utc': '2024-03-11 05:40Z',
#     'local': '2024-03-11 06:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:44Z',
#     'local': '2024-03-11 06:44+01:00'},
#    'runwayTime': {'utc': '2024-03-11 05:44Z',
#     'local': '2024-03-11 06:44+01:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:25Z',
#     'local': '2024-03-11 08:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:16Z',
#     'local': '2024-03-11 08:16+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4873',
#   'callSign': 'EJU40FD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICK', 'modeS': '440053', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LOWG', 'iata': 'GRZ', 'name': 'Graz'},
#    'scheduledTime': {'utc': '2024-03-11 06:30Z',
#     'local': '2024-03-11 07:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:28Z',
#     'local': '2024-03-11 07:28+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:28Z',
#     'local': '2024-03-11 07:28+01:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:40Z',
#     'local': '2024-03-11 08:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:26Z',
#     'local': '2024-03-11 08:26+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8347',
#   'callSign': 'EWG2KA',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EUW', 'modeS': '4D240E', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LOWG', 'iata': 'GRZ', 'name': 'Graz'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:40Z',
#     'local': '2024-03-11 08:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:26Z',
#     'local': '2024-03-11 08:26+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 8833',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EUW', 'modeS': '4D240E', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LYBE', 'iata': 'BEG', 'name': 'Belgrade'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:00Z',
#     'local': '2024-03-11 09:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:40Z',
#     'local': '2024-03-11 08:40+01:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'JA 350',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LY-LOC', 'modeS': '503CC0', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'JetSMART', 'iata': 'JA', 'icao': 'JAT'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main'},
#    'scheduledTime': {'utc': '2024-03-11 06:45Z',
#     'local': '2024-03-11 07:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:45Z',
#     'local': '2024-03-11 07:45+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:04Z',
#     'local': '2024-03-11 08:04+01:00'},
#    'terminal': '1',
#    'checkInDesk': '259-488',
#    'gate': 'A18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:55Z',
#     'local': '2024-03-11 08:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:48Z',
#     'local': '2024-03-11 08:48+01:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 174',
#   'callSign': 'DLH7EE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIZZ',
#    'modeS': '3C675A',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#    'scheduledTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 07:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:26Z',
#     'local': '2024-03-11 07:26+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:49Z',
#     'local': '2024-03-11 07:49+01:00'},
#    'checkInDesk': '1',
#    'gate': 'B38',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:45Z',
#     'local': '2024-03-11 08:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:49Z',
#     'local': '2024-03-11 08:49+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 974',
#   'callSign': 'SWR97Y',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'YL-AAX', 'modeS': '502D28', 'model': 'Airbus A220-300'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#    'scheduledTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 08:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 08:00+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:10Z',
#     'local': '2024-03-11 09:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:52Z',
#     'local': '2024-03-11 08:52+01:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1930',
#   'callSign': 'DLH2X',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#    'scheduledTime': {'utc': '2024-03-11 06:30Z',
#     'local': '2024-03-11 07:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:26Z',
#     'local': '2024-03-11 07:26+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:39Z',
#     'local': '2024-03-11 07:39+01:00'},
#    'checkInDesk': '123',
#    'gate': 'D11',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:05Z',
#     'local': '2024-03-11 09:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:58Z',
#     'local': '2024-03-11 08:58+01:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'DY 1102',
#   'callSign': 'NOZ2XM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LN-NII', 'modeS': '47945C', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#  {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#    'scheduledTime': {'utc': '2024-03-11 06:25Z',
#     'local': '2024-03-11 07:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:50Z',
#     'local': '2024-03-11 07:50+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:50Z',
#     'local': '2024-03-11 07:50+01:00'},
#    'terminal': '2F',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:03Z',
#     'local': '2024-03-11 09:03+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1434',
#   'callSign': 'AFR1434',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-HEPG', 'modeS': '3991E6', 'model': 'Airbus A320'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#    'scheduledTime': {'utc': '2024-03-11 06:55Z',
#     'local': '2024-03-11 07:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:01Z',
#     'local': '2024-03-11 08:01+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:03Z',
#     'local': '2024-03-11 08:03+01:00'},
#    'checkInDesk': '08',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:07Z',
#     'local': '2024-03-11 09:07+01:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 163',
#   'callSign': 'RYR11EH',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VUN', 'modeS': '4D234D', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'ELLX',
#     'iata': 'LUX',
#     'name': 'Luxembourg'},
#    'scheduledTime': {'utc': '2024-03-11 05:45Z',
#     'local': '2024-03-11 06:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:39Z',
#     'local': '2024-03-11 07:39+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:48Z',
#     'local': '2024-03-11 07:48+01:00'},
#    'terminal': 'A',
#    'gate': 'B02',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 07:15Z',
#     'local': '2024-03-11 08:15+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:10Z',
#     'local': '2024-03-11 09:10+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LG 9471',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LX-LQB',
#    'modeS': '4D00D6',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#  {'departure': {'airport': {'name': 'Unknown'}, 'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:16Z',
#     'local': '2024-03-11 09:16+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:16Z',
#     'local': '2024-03-11 09:16+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:16Z',
#     'local': '2024-03-11 09:16+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'UAG 27G',
#   'callSign': 'UAG27G',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'airline': {'name': 'UAG'}},
#  {'departure': {'airport': {'icao': 'LEPA',
#     'iata': 'PMI',
#     'name': 'Palma De Mallorca'},
#    'scheduledTime': {'utc': '2024-03-11 05:55Z',
#     'local': '2024-03-11 06:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 05:49Z',
#     'local': '2024-03-11 06:49+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:03Z',
#     'local': '2024-03-11 07:03+01:00'},
#    'terminal': 'N',
#    'checkInDesk': '046-050',
#    'gate': 'C54',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:40Z',
#     'local': '2024-03-11 09:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:17Z',
#     'local': '2024-03-11 09:17+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:22Z',
#     'local': '2024-03-11 09:22+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 6892',
#   'callSign': 'EWG27ZJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EXW', 'modeS': '4D2412', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen'},
#    'scheduledTime': {'utc': '2024-03-11 07:10Z',
#     'local': '2024-03-11 08:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:10Z',
#     'local': '2024-03-11 08:10+01:00'},
#    'terminal': 'erminal3',
#    'gate': 'A12',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:24Z',
#     'local': '2024-03-11 09:24+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8227',
#   'callSign': 'EWG42XB',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'terminal': '1',
#    'gate': 'A33',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5321',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LLBG',
#     'iata': 'TLV',
#     'name': 'Tel Aviv Yafo'},
#    'scheduledTime': {'utc': '2024-03-11 04:00Z',
#     'local': '2024-03-11 06:00+02:00'},
#    'terminal': '3',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:25Z',
#     'local': '2024-03-11 09:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:22Z',
#     'local': '2024-03-11 09:22+01:00'},
#    'terminal': '1',
#    'gate': 'X19',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LY 2371',
#   'callSign': 'ELY2371',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '4X-EKB', 'modeS': '738064', 'model': 'Boeing 737'},
#   'airline': {'name': 'El Al', 'iata': 'LY', 'icao': 'ELY'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam'},
#    'scheduledTime': {'utc': '2024-03-11 07:05Z',
#     'local': '2024-03-11 08:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:03Z',
#     'local': '2024-03-11 08:03+01:00'},
#    'runwayTime': {'utc': '2024-03-11 07:25Z',
#     'local': '2024-03-11 08:25+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'B31',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:25Z',
#     'local': '2024-03-11 09:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:25Z',
#     'local': '2024-03-11 09:25+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1821',
#   'callSign': 'KLM69H',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-EXH', 'modeS': '4852F5', 'model': 'Embraer 175'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'LTFM', 'iata': 'IST', 'name': 'Istanbul'},
#    'scheduledTime': {'utc': '2024-03-11 05:50Z',
#     'local': '2024-03-11 08:50+03:00'},
#    'revisedTime': {'utc': '2024-03-11 05:50Z',
#     'local': '2024-03-11 08:50+03:00'},
#    'checkInDesk': 'E-F',
#    'gate': 'F18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:45Z',
#     'local': '2024-03-11 09:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:27Z',
#     'local': '2024-03-11 09:27+01:00'},
#    'terminal': '1',
#    'gate': 'X01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1721',
#   'callSign': 'THY8VN',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-LOB', 'modeS': '4BB1E2', 'model': 'Airbus A330'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#    'scheduledTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 06:20+00:00'},
#    'revisedTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 06:20+00:00'},
#    'runwayTime': {'utc': '2024-03-11 06:34Z',
#     'local': '2024-03-11 06:34+00:00'},
#    'terminal': '2',
#    'checkInDesk': '29-56',
#    'gate': '418',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:40Z',
#     'local': '2024-03-11 09:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:30Z',
#     'local': '2024-03-11 09:30+01:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EI 332',
#   'callSign': 'EIN3JE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-GAL', 'modeS': '4CA836', 'model': 'Airbus A320'},
#   'airline': {'name': 'Aer Lingus', 'iata': 'EI', 'icao': 'EIN'}},
#  {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#    'scheduledTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 06:20+00:00'},
#    'revisedTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 06:20+00:00'},
#    'runwayTime': {'utc': '2024-03-11 06:37Z',
#     'local': '2024-03-11 06:37+00:00'},
#    'terminal': '1',
#    'checkInDesk': '1204-1319',
#    'gate': '104',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:35Z',
#     'local': '2024-03-11 09:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:35Z',
#     'local': '2024-03-11 09:35+01:00'},
#    'terminal': '2',
#    'gate': 'Z42',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3669',
#   'callSign': 'RYR23SD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EXE', 'modeS': '4CAA60', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen'},
#    'scheduledTime': {'utc': '2024-03-11 07:50Z',
#     'local': '2024-03-11 08:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:50Z',
#     'local': '2024-03-11 08:50+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:01Z',
#     'local': '2024-03-11 09:01+01:00'},
#    'terminal': 'erminal2',
#    'gate': 'F7',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:55Z',
#     'local': '2024-03-11 09:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:43Z',
#     'local': '2024-03-11 09:43+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5262',
#   'callSign': 'EJU5191',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen'},
#    'scheduledTime': {'utc': '2024-03-11 07:50Z',
#     'local': '2024-03-11 08:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:50Z',
#     'local': '2024-03-11 08:50+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:01Z',
#     'local': '2024-03-11 09:01+01:00'},
#    'terminal': 'erminal2',
#    'gate': 'F7',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:55Z',
#     'local': '2024-03-11 09:55+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:43Z',
#     'local': '2024-03-11 09:43+01:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5262',
#   'callSign': 'EJU5191',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EGCC',
#     'iata': 'MAN',
#     'name': 'Manchester'},
#    'scheduledTime': {'utc': '2024-03-11 06:50Z',
#     'local': '2024-03-11 06:50+00:00'},
#    'revisedTime': {'utc': '2024-03-11 06:49Z',
#     'local': '2024-03-11 06:49+00:00'},
#    'runwayTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 07:00+00:00'},
#    'terminal': '1',
#    'gate': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:50Z',
#     'local': '2024-03-11 09:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:45Z',
#     'local': '2024-03-11 09:45+01:00'},
#    'terminal': '1',
#    'gate': 'X03',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 2199',
#   'callSign': 'EZY73FB',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-UZHO', 'modeS': '40756D', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart'},
#    'scheduledTime': {'utc': '2024-03-11 07:45Z',
#     'local': '2024-03-11 08:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:45Z',
#     'local': '2024-03-11 08:45+01:00'},
#    'terminal': '1',
#    'gate': '140',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:00Z',
#     'local': '2024-03-11 10:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:48Z',
#     'local': '2024-03-11 09:48+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8001',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENH', 'modeS': '3C55C8', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:00Z',
#     'local': '2024-03-11 10:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:48Z',
#     'local': '2024-03-11 09:48+01:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5392',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENH', 'modeS': '3C55C8', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#    'scheduledTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 07:00+00:00'},
#    'revisedTime': {'utc': '2024-03-11 07:00Z',
#     'local': '2024-03-11 07:00+00:00'},
#    'runwayTime': {'utc': '2024-03-11 07:20Z',
#     'local': '2024-03-11 07:20+00:00'},
#    'checkInDesk': '55-61',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:50Z',
#     'local': '2024-03-11 09:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:51Z',
#     'local': '2024-03-11 09:51+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:57Z',
#     'local': '2024-03-11 09:57+01:00'},
#    'terminal': '1',
#    'gate': 'X06',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 2601',
#   'callSign': 'EZY13PJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-UZHK',
#    'modeS': '40756A',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#    'scheduledTime': {'utc': '2024-03-11 07:15Z',
#     'local': '2024-03-11 07:15+00:00'},
#    'revisedTime': {'utc': '2024-03-11 07:19Z',
#     'local': '2024-03-11 07:19+00:00'},
#    'runwayTime': {'utc': '2024-03-11 07:20Z',
#     'local': '2024-03-11 07:20+00:00'},
#    'terminal': '5',
#    'checkInDesk': 'C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:10Z',
#     'local': '2024-03-11 10:10+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:53Z',
#     'local': '2024-03-11 09:53+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:00Z',
#     'local': '2024-03-11 10:00+01:00'},
#    'terminal': '1',
#    'gate': 'X10',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 990',
#   'callSign': 'BAW990',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EUPG', 'modeS': '400877', 'model': 'Airbus A319'},
#   'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:54Z',
#     'local': '2024-03-11 09:54+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:54Z',
#     'local': '2024-03-11 09:54+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:54Z',
#     'local': '2024-03-11 09:54+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': '4U 8001',
#   'callSign': 'GWI8001',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AENH', 'modeS': '3C55C8', 'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'icao': 'LFST',
#     'iata': 'SXB',
#     'name': 'Strasbourg'},
#    'scheduledTime': {'utc': '2024-03-11 07:55Z',
#     'local': '2024-03-11 08:55+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:25Z',
#     'local': '2024-03-11 10:25+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:55Z',
#     'local': '2024-03-11 09:55+01:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'V7 2596',
#   'callSign': 'VOE2596',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-NPB', 'modeS': '346649', 'model': 'Airbus A320'},
#   'airline': {'name': 'Volotea', 'iata': 'V7', 'icao': 'VOE'}},
#  {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#    'scheduledTime': {'utc': '2024-03-11 07:55Z',
#     'local': '2024-03-11 08:55+01:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:05Z',
#     'local': '2024-03-11 10:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:57Z',
#     'local': '2024-03-11 09:57+01:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8059',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LEBL',
#     'iata': 'BCN',
#     'name': 'Barcelona'},
#    'scheduledTime': {'utc': '2024-03-11 06:20Z',
#     'local': '2024-03-11 07:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 06:32Z',
#     'local': '2024-03-11 07:32+01:00'},
#    'runwayTime': {'utc': '2024-03-11 06:46Z',
#     'local': '2024-03-11 07:46+01:00'},
#    'terminal': '1',
#    'checkInDesk': '501-514',
#    'gate': 'B61',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 09:05Z',
#     'local': '2024-03-11 10:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:58Z',
#     'local': '2024-03-11 09:58+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'VY 1882',
#   'callSign': 'VLG1882',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EC-LOC', 'modeS': '344157', 'model': 'Airbus A320'},
#   'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main'},
#    'scheduledTime': {'utc': '2024-03-11 07:45Z',
#     'local': '2024-03-11 08:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 07:45Z',
#     'local': '2024-03-11 08:45+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:08Z',
# ...
#    'terminal': '1',
#    'gate': 'B10',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 178',
#   'callSign': 'DLH8HR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIUM', 'modeS': '3C66AD', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#    'scheduledTime': {'utc': '2024-03-11 05:25Z',
#     'local': '2024-03-11 07:25+02:00'},
#    'revisedTime': {'utc': '2024-03-11 07:44Z',
#     'local': '2024-03-11 09:44+02:00'},
#    'terminal': 'I',
#    'checkInDesk': '9----13',
#    'gate': 'A01',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 08:20Z',
#     'local': '2024-03-11 09:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:59Z',
#     'local': '2024-03-11 10:59+01:00'},
#    'terminal': '1',
#    'gate': 'Y03',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'TV 720',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#   'airline': {'name': 'Tibet', 'iata': 'TV', 'icao': 'TBA'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam'},
#    'scheduledTime': {'utc': '2024-03-11 08:45Z',
#     'local': '2024-03-11 09:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:51Z',
#     'local': '2024-03-11 09:51+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:04Z',
#     'local': '2024-03-11 10:04+01:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'C11',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#     'local': '2024-03-11 11:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:03Z',
#     'local': '2024-03-11 11:03+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:09Z',
#     'local': '2024-03-11 11:09+01:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1823',
#   'callSign': 'KLM95E',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#    'scheduledTime': {'utc': '2024-03-11 06:45Z',
#     'local': '2024-03-11 09:45+03:00'},
#    'revisedTime': {'utc': '2024-03-11 06:45Z',
#     'local': '2024-03-11 09:45+03:00'},
#    'terminal': '1',
#    'checkInDesk': '146-148',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#     'local': '2024-03-11 11:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:06Z',
#     'local': '2024-03-11 11:06+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:12Z',
#     'local': '2024-03-11 11:12+01:00'},
#    'terminal': '1',
#    'gate': 'X19',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 5007',
#   'callSign': 'PGT99EZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-NCF',
#    'modeS': '4BB866',
#    'model': 'Airbus A320 (Sharklets)'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'LGAV', 'iata': 'ATH', 'name': 'Athens'},
#    'scheduledTime': {'utc': '2024-03-11 07:46Z',
#     'local': '2024-03-11 09:46+02:00'},
#    'revisedTime': {'utc': '2024-03-11 07:46Z',
#     'local': '2024-03-11 09:46+02:00'},
#    'runwayTime': {'utc': '2024-03-11 07:46Z',
#     'local': '2024-03-11 09:46+02:00'},
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:07Z',
#     'local': '2024-03-11 11:07+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:07Z',
#     'local': '2024-03-11 11:07+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:07Z',
#     'local': '2024-03-11 11:07+01:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'TR 720',
#   'callSign': 'TGW720',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9V-OFH', 'modeS': '76BCC8', 'model': 'Boeing 787-8'},
#   'airline': {'name': 'Scoot', 'iata': 'TR', 'icao': 'TGW'}},
#  {'departure': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#    'scheduledTime': {'utc': '2024-03-11 08:40Z',
#     'local': '2024-03-11 09:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:00Z',
#     'local': '2024-03-11 10:00+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:00Z',
#     'local': '2024-03-11 10:00+01:00'},
#    'checkInDesk': '05',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#     'local': '2024-03-11 11:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:10Z',
#     'local': '2024-03-11 11:10+01:00'},
#    'terminal': '1',
#    'gate': 'B06',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'SN 2581',
#   'callSign': 'BEL8CE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#   'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#  {'departure': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#    'scheduledTime': {'utc': '2024-03-11 08:25Z',
#     'local': '2024-03-11 08:25+00:00'},
#    'revisedTime': {'utc': '2024-03-11 08:32Z',
#     'local': '2024-03-11 08:32+00:00'},
#    'runwayTime': {'utc': '2024-03-11 08:38Z',
#     'local': '2024-03-11 08:38+00:00'},
#    'gate': '8',
#    'runway': '27',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:05Z',
#     'local': '2024-03-11 11:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:13Z',
#     'local': '2024-03-11 11:13+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 8491',
#   'callSign': 'CFE76JZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-LCYT', 'modeS': '406B6D', 'model': 'Embraer 190'},
#   'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#     'local': '2024-03-11 11:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:26Z',
#     'local': '2024-03-11 11:26+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5144',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#    'scheduledTime': {'utc': '2024-03-11 08:35Z',
#     'local': '2024-03-11 09:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 08:54Z',
#     'local': '2024-03-11 09:54+01:00'},
#    'runwayTime': {'utc': '2024-03-11 08:54Z',
#     'local': '2024-03-11 09:54+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#     'local': '2024-03-11 11:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:26Z',
#     'local': '2024-03-11 11:26+01:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'B1',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5144',
#   'callSign': 'EJU70ZR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm'},
#    'scheduledTime': {'utc': '2024-03-11 09:05Z',
#     'local': '2024-03-11 10:05+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:05Z',
#     'local': '2024-03-11 10:05+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:12Z',
#     'local': '2024-03-11 10:12+01:00'},
#    'terminal': '5',
#    'checkInDesk': '18-0',
#    'gate': 'D12',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#     'local': '2024-03-11 11:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:31Z',
#     'local': '2024-03-11 11:31+01:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'D8 4505',
#   'callSign': 'NSZ4505',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-RXB', 'modeS': '4ACB02', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#  {'departure': {'airport': {'icao': 'ORER', 'iata': 'EBL', 'name': 'Arbil'},
#    'scheduledTime': {'utc': '2024-03-11 06:00Z',
#     'local': '2024-03-11 09:00+03:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:30Z',
#     'local': '2024-03-11 11:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:35Z',
#     'local': '2024-03-11 11:35+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:42Z',
#     'local': '2024-03-11 11:42+01:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'UD 445',
#   'callSign': 'UBD445',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LZ-BHM', 'modeS': '452087', 'model': 'Airbus A320'},
#   'airline': {'name': 'UR', 'iata': 'UD', 'icao': 'UBD'}},
#  {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#    'scheduledTime': {'utc': '2024-03-11 08:35Z',
#     'local': '2024-03-11 09:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:19Z',
#     'local': '2024-03-11 10:19+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:22Z',
#     'local': '2024-03-11 10:22+01:00'},
#    'checkInDesk': '1-17',
#    'gate': 'A1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#     'local': '2024-03-11 11:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:39Z',
#     'local': '2024-03-11 11:39+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:45Z',
#     'local': '2024-03-11 11:45+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5182',
#   'callSign': 'EJU39TE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#    'scheduledTime': {'utc': '2024-03-11 08:35Z',
#     'local': '2024-03-11 09:35+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:19Z',
#     'local': '2024-03-11 10:19+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:22Z',
#     'local': '2024-03-11 10:22+01:00'},
#    'terminal': '1',
#    'checkInDesk': '1-17',
#    'gate': 'A1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:20Z',
#     'local': '2024-03-11 11:20+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:39Z',
#     'local': '2024-03-11 11:39+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:45Z',
#     'local': '2024-03-11 11:45+01:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5182',
#   'callSign': 'EJU39TE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IVS', 'modeS': '4400E3', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EKCH',
#     'iata': 'CPH',
#     'name': 'Copenhagen'},
#    'scheduledTime': {'utc': '2024-03-11 10:00Z',
#     'local': '2024-03-11 11:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:00Z',
#     'local': '2024-03-11 11:00+01:00'},
#    'terminal': 'erminal2',
#    'gate': 'A8',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 11:00Z',
#     'local': '2024-03-11 12:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:43Z',
#     'local': '2024-03-11 11:43+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:44Z',
#     'local': '2024-03-11 11:44+01:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'D8 3302',
#   'callSign': 'NSZ3302',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LN-NIG', 'modeS': '4794F2', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#  {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#    'scheduledTime': {'utc': '2024-03-11 08:45Z',
#     'local': '2024-03-11 09:45+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:28Z',
#     'local': '2024-03-11 10:28+01:00'},
#    'runwayTime': {'utc': '2024-03-11 09:28Z',
#     'local': '2024-03-11 10:28+01:00'},
#    'terminal': '2F',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:30Z',
#     'local': '2024-03-11 11:30+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:47Z',
#     'local': '2024-03-11 11:47+01:00'},
#    'terminal': '1',
#    'gate': 'A06',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1734',
#   'callSign': 'AFR69NH',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-GTAK', 'modeS': '394C0A', 'model': 'Airbus A321'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#    'scheduledTime': {'utc': '2024-03-11 09:50Z',
#     'local': '2024-03-11 10:50+01:00'},
#    'revisedTime': {'utc': '2024-03-11 09:50Z',
#     'local': '2024-03-11 10:50+01:00'},
#    'runwayTime': {'utc': '2024-03-11 10:07Z',
#     'local': '2024-03-11 11:07+01:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 11:00Z',
#     'local': '2024-03-11 12:00+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:51Z',
#     'local': '2024-03-11 11:51+01:00'},
#    'terminal': '1',
#    'gate': 'B17',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 2206',
#   'callSign': 'DLH4X',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIBQ', 'modeS': '3C6451', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LOWS', 'iata': 'SZG', 'name': 'Salzburg'},
#    'scheduledTime': {'utc': '2024-03-11 09:35Z',
#     'local': '2024-03-11 10:35+01:00'},
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#     'local': '2024-03-11 11:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:53Z',
#     'local': '2024-03-11 11:53+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 4342',
#   'callSign': 'EWG8WT',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EWH',
#    'modeS': '4D2418',
#    'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LOWS', 'iata': 'SZG', 'name': 'Salzburg'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-03-11 10:40Z',
#     'local': '2024-03-11 11:40+01:00'},
#    'revisedTime': {'utc': '2024-03-11 10:53Z',
#     'local': '2024-03-11 11:53+01:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 8721',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-EWH', 'model': 'Airbus A320-200 (sharklets)'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}}]

# %% [markdown]
# The square brackets at the beginning of `flights_json` indicate that it represents a list-like structure. Since we're dealing with a list, we can iterate through its elements to access and process the data. Let's start by examining the first element in the list.

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'},
#   'scheduledTime': {'utc': '2024-03-10 23:35Z',
#    'local': '2024-03-11 02:35+03:00'},
#   'quality': ['Basic']},
#  'arrival': {'scheduledTime': {'utc': '2024-03-11 05:50Z',
#    'local': '2024-03-11 06:50+01:00'},
#   'revisedTime': {'utc': '2024-03-11 05:57Z',
#    'local': '2024-03-11 06:57+01:00'},
#   'runwayTime': {'utc': '2024-03-11 06:02Z',
#    'local': '2024-03-11 07:02+01:00'},
#   'terminal': '1',
#   'gate': 'X07',
#   'baggageBelt': 'A3',
#   'quality': ['Basic', 'Live']},
#  'number': 'QR 79',
#  'callSign': 'QTR7R',
#  'status': 'Arrived',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#  'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}}

# %%
flights_json["arrivals"][0]#.keys()
# Out:
# {'departure': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'},
#   'scheduledTime': {'utc': '2024-03-10 23:35Z',
#    'local': '2024-03-11 02:35+03:00'},
#   'quality': ['Basic']},
#  'arrival': {'scheduledTime': {'utc': '2024-03-11 05:50Z',
#    'local': '2024-03-11 06:50+01:00'},
#   'revisedTime': {'utc': '2024-03-11 05:57Z',
#    'local': '2024-03-11 06:57+01:00'},
#   'runwayTime': {'utc': '2024-03-11 06:02Z',
#    'local': '2024-03-11 07:02+01:00'},
#   'terminal': '1',
#   'gate': 'X07',
#   'baggageBelt': 'A3',
#   'quality': ['Basic', 'Live']},
#  'number': 'QR 79',
#  'callSign': 'QTR7R',
#  'status': 'Arrived',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#  'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}}

# %% [markdown]
# Looking at the first element of the json and the available keys, we can select the information we think would be important for our dataframe.
# - Departure airport icao
# - scheduled arrival time, local
# - flight number

# %% [markdown]
# # Using for loops

# %% [markdown]
# ## Making the DataFrame

# %%
flight_items = []

for item in flights_json["arrivals"]:
  flight_item = {
      "arrival_airport_icao": icao,
      "departure_airport_icao": item["departure"]["airport"].get("icao", None),
      "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
      'arrival_terminal': item['arrival'].get('terminal', None),
      "flight_number": item.get("number", None)
  }

  flight_items.append(flight_item)

flights_df = pd.DataFrame(flight_items)

flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao  scheduled_arrival_time  \
# 0                 EDDB                   OTHH  2024-03-11 06:50+01:00
# 1                 EDDB                   LFSB  2024-03-11 07:40+01:00
# 2                 EDDB                   LFSB  2024-03-11 07:40+01:00
# 3                 EDDB                   KEWR  2024-03-11 07:55+01:00
# 4                 EDDB                   EDDK  2024-03-11 07:55+01:00
#
#   arrival_terminal flight_number
# 0                1         QR 79
# 1                1       DS 1185
# 2                1       U2 1185
# 3                1        UA 962
# 4                1         EW 12

# %% [markdown]
# Let's get rid of the `+01:00` from `scheduled_arrival_time`.

# %%
flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                 EDDB                   OTHH       2024-03-11 06:50
# 1                 EDDB                   LFSB       2024-03-11 07:40
# 2                 EDDB                   LFSB       2024-03-11 07:40
# 3                 EDDB                   KEWR       2024-03-11 07:55
# 4                 EDDB                   EDDK       2024-03-11 07:55
#
#   arrival_terminal flight_number
# 0                1         QR 79
# 1                1       DS 1185
# 2                1       U2 1185
# 3                1        UA 962
# 4                1         EW 12

# %% [markdown]
# While string slicing provides a quick solution to correcting the `scheduled_arrival_time` column, it's not the most robust approach. This is because it assumes that every cell in the column has the `+01:00` time zone offset. If there are cells without this offset, slicing would remove part of the time value, leading to inaccurate results.
#
# A more robust solution would involve using the `re.sub()` function from the re module. Feel free to look into this if you have extra time and are curious.

# %% [markdown]
# ## Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': api_key
          }

      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            'arrival_terminal': item['arrival'].get('terminal', None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %%
icao_list = ["EDDB", "EDDF"]

get_flight_data(icao_list)
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   OTHH    2024-03-12 06:50:00
# 1                   EDDB                   EVRA    2024-03-12 07:35:00
# 2                   EDDB                   LHBP    2024-03-12 07:45:00
# 3                   EDDB                   UGKO    2024-03-12 07:50:00
# 4                   EDDB                   EVRA    2024-03-12 07:55:00
# ..                   ...                    ...                    ...
# 867                 EDDF                   LPPT    2024-03-12 22:40:00
# 868                 EDDF                   LTFM    2024-03-12 22:05:00
# 869                 EDDF                   LEMD    2024-03-12 22:45:00
# 870                 EDDF                   LPMA    2024-03-12 22:30:00
# 871                 EDDF                   HEGN    2024-03-12 22:15:00
#
#     arrival_terminal flight_number   data_retrieved_at
# 0                  1         QR 79 2024-03-11 16:23:27
# 1                  2       FR 2600 2024-03-11 16:23:27
# 2                  2       W6 2315 2024-03-11 16:23:27
# 3                  2       W6 6407 2024-03-11 16:23:27
# 4                  1       A3 3219 2024-03-11 16:23:27
# ..               ...           ...                 ...
# 867                1        TP 574 2024-03-11 16:23:30
# 868                1       UA 6902 2024-03-11 16:23:30
# 869                2       VY 5520 2024-03-11 16:23:30
# 870                2       X3 2807 2024-03-11 16:23:30
# 871                2       X3 6103 2024-03-11 16:23:30
#
# [872 rows x 6 columns]

# %% [markdown]
# Your flight function can now be incorporated with your other functions to send and receive data from your SQL database.

# %% [markdown]
# # Using pd.json_normalize

# %%
def tomorrows_flight_arrivals(icao_list):

    api_key = "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"

    berlin_timezone = timezone('Europe/Berlin')
    today = datetime.now(berlin_timezone).date()
    tomorrow = (today + timedelta(days=1))

    list_for_arrivals_df = []

    for icao in icao_list:

        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"direction":"Arrival","withCancelled":"false"}

            headers = {
                "X-RapidAPI-Key": "12c7bd34d2msha978e1852a9e04dp17b222jsnd5260f196022",
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.request("GET", url, headers=headers, params=querystring)
            flights_resp = response.json()

            arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "airline.name", "movement.scheduledTime.local", "movement.terminal", "movement.airport.name", "movement.airport.icao"]]
            arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "airline.name": "airline", "movement.scheduledTime.local": "arrival_time", "movement.terminal": "arrival_terminal", "movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
            arrivals_df["arrival_airport_icao"] = icao
            arrivals_df["data_retrieved_on"] = datetime.now().date()
            arrivals_df = arrivals_df[["arrival_airport_icao", "flight_number", "airline", "arrival_time", "arrival_terminal", "departure_city", "departure_airport_icao", "data_retrieved_on"]]

            # fixing arrival_time
            arrivals_df["arrival_time"] = arrivals_df["arrival_time"].str.split("+").str[0]

            list_for_arrivals_df.append(arrivals_df)

    return pd.concat(list_for_arrivals_df, ignore_index=True)

# %%
icao_list = ["EDDF", "EDDB"]

tomorrows_flight_arrivals(icao_list)
# Out:
#     arrival_airport_icao flight_number            airline      arrival_time  \
# 0                   EDDF        4Y 133  Discover Airlines  2024-03-12 05:20
# 1                   EDDF       AC 7404         Air Canada  2024-03-12 05:55
# 2                   EDDF       AC 9019         Air Canada  2024-03-12 05:15
# 3                   EDDF       AC 9081         Air Canada  2024-03-12 05:45
# 4                   EDDF       AC 9512         Air Canada  2024-03-12 05:40
# ..                   ...           ...                ...               ...
# 867                 EDDB       I2 3674     Iberia Express  2024-03-12 23:05
# 868                 EDDB       IB 3674             Iberia  2024-03-12 23:05
# 869                 EDDB       SN 2591           Brussels  2024-03-12 22:20
# 870                 EDDB        LX 962              SWISS  2024-03-12 22:20
# 871                 EDDB        OS 239           Austrian  2024-03-12 22:15
#
#     arrival_terminal     departure_city departure_airport_icao  \
# 0                  1           Windhoek                   FYWH
# 1                  1            Bangkok                   VTBS
# 2                  1            Jo'anna                   FAOR
# 3                  1              Dubai                   OMDB
# 4                  1  Frankfurt-am-Main                   EDDF
# ..               ...                ...                    ...
# 867                1             Madrid                   LEMD
# 868                1             Madrid                   LEMD
# 869                1           Brussels                   EBBR
# 870                1             Zurich                   LSZH
# 871                1             Vienna                   LOWW
#
#     data_retrieved_on
# 0          2024-03-11
# 1          2024-03-11
# 2          2024-03-11
# 3          2024-03-11
# 4          2024-03-11
# ..                ...
# 867        2024-03-11
# 868        2024-03-11
# 869        2024-03-11
# 870        2024-03-11
# 871        2024-03-11
#
# [872 rows x 8 columns]
