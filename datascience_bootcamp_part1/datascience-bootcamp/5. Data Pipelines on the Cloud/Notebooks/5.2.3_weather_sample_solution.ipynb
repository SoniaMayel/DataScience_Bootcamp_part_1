# %%
import pandas as pd
import requests
from datetime import datetime

# using colab secrets to store our passwords and keys
from google.colab import userdata

# %% [markdown]
# # Making the API call and viewing the json

# %%
city = 'Berlin'
API_key = userdata.get('openWeatherApi')

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")

response = requests.get(url)
json = response.json()

json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1710255600,
#    'main': {'temp': 14.79,
#     'feels_like': 13.73,
#     'temp_min': 12.28,
#     'temp_max': 14.79,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 1008,
#     'humidity': 54,
#     'temp_kf': 2.51},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.23, 'deg': 290, 'gust': 4.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-12 15:00:00'},
#   {'dt': 1710266400,
#    'main': {'temp': 13.33,
#     'feels_like': 12.26,
#     'temp_min': 10.4,
#     'temp_max': 13.33,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 1009,
#     'humidity': 59,
#     'temp_kf': 2.93},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 2.54, 'deg': 280, 'gust': 6.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-12 18:00:00'},
#   {'dt': 1710277200,
#    'main': {'temp': 11,
#     'feels_like': 9.96,
#     'temp_min': 9.1,
#     'temp_max': 11,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1011,
#     'humidity': 69,
#     'temp_kf': 1.9},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 2.81, 'deg': 276, 'gust': 5.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-12 21:00:00'},
#   {'dt': 1710288000,
#    'main': {'temp': 7.92,
#     'feels_like': 6.45,
#     'temp_min': 7.92,
#     'temp_max': 7.92,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.38, 'deg': 259, 'gust': 4.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-13 00:00:00'},
#   {'dt': 1710298800,
#    'main': {'temp': 6.15,
#     'feels_like': 4.63,
#     'temp_min': 6.15,
#     'temp_max': 6.15,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 2.08, 'deg': 249, 'gust': 4.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-13 03:00:00'},
#   {'dt': 1710309600,
#    'main': {'temp': 5.43,
#     'feels_like': 4.05,
#     'temp_min': 5.43,
#     'temp_max': 5.43,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 1.83, 'deg': 244, 'gust': 3.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-13 06:00:00'},
#   {'dt': 1710320400,
#    'main': {'temp': 9.94,
#     'feels_like': 8.88,
#     'temp_min': 9.94,
#     'temp_max': 9.94,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.32, 'deg': 216, 'gust': 3.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-13 09:00:00'},
#   {'dt': 1710331200,
#    'main': {'temp': 13.16,
#     'feels_like': 11.81,
#     'temp_min': 13.16,
#     'temp_max': 13.16,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3.37, 'deg': 209, 'gust': 4.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-13 12:00:00'},
#   {'dt': 1710342000,
#    'main': {'temp': 13.16,
#     'feels_like': 11.81,
#     'temp_min': 13.16,
#     'temp_max': 13.16,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 3.69, 'deg': 218, 'gust': 4.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-13 15:00:00'},
#   {'dt': 1710352800,
#    'main': {'temp': 10.06,
#     'feels_like': 8.79,
#     'temp_min': 10.06,
#     'temp_max': 10.06,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 2.78, 'deg': 219, 'gust': 6.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-13 18:00:00'},
#   {'dt': 1710363600,
#    'main': {'temp': 9.59,
#     'feels_like': 8.13,
#     'temp_min': 9.59,
#     'temp_max': 9.59,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 2.82, 'deg': 206, 'gust': 7.08},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-13 21:00:00'},
#   {'dt': 1710374400,
#    'main': {'temp': 9.04,
#     'feels_like': 7.71,
#     'temp_min': 9.04,
#     'temp_max': 9.04,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.46, 'deg': 211, 'gust': 5.64},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-14 00:00:00'},
#   {'dt': 1710385200,
#    'main': {'temp': 9.06,
#     'feels_like': 7.85,
#     'temp_min': 9.06,
#     'temp_max': 9.06,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.31, 'deg': 216, 'gust': 6.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-14 03:00:00'},
#   {'dt': 1710396000,
#    'main': {'temp': 8.89,
#     'feels_like': 7.61,
#     'temp_min': 8.89,
#     'temp_max': 8.89,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.36, 'deg': 206, 'gust': 5.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-14 06:00:00'},
#   {'dt': 1710406800,
#    'main': {'temp': 11.92,
#     'feels_like': 11.13,
#     'temp_min': 11.92,
#     'temp_max': 11.92,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1011,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.65, 'deg': 233, 'gust': 6.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-14 09:00:00'},
#   {'dt': 1710417600,
#    'main': {'temp': 14.85,
#     'feels_like': 13.93,
#     'temp_min': 14.85,
#     'temp_max': 14.85,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1010,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.38, 'deg': 252, 'gust': 6.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-14 12:00:00'},
#   {'dt': 1710428400,
#    'main': {'temp': 15.02,
#     'feels_like': 14.12,
#     'temp_min': 15.02,
#     'temp_max': 15.02,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.1, 'deg': 241, 'gust': 4.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-14 15:00:00'},
#   {'dt': 1710439200,
#    'main': {'temp': 12.5,
#     'feels_like': 11.66,
#     'temp_min': 12.5,
#     'temp_max': 12.5,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.39, 'deg': 195, 'gust': 5.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-14 18:00:00'},
#   {'dt': 1710450000,
#    'main': {'temp': 11.18,
#     'feels_like': 10.39,
#     'temp_min': 11.18,
#     'temp_max': 11.18,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.61, 'deg': 189, 'gust': 6.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-14 21:00:00'},
#   {'dt': 1710460800,
#    'main': {'temp': 10.17,
#     'feels_like': 9.36,
#     'temp_min': 10.17,
#     'temp_max': 10.17,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.83, 'deg': 184, 'gust': 7.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-15 00:00:00'},
#   {'dt': 1710471600,
#    'main': {'temp': 9.66,
#     'feels_like': 8.15,
#     'temp_min': 9.66,
#     'temp_max': 9.66,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.92, 'deg': 189, 'gust': 8.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-15 03:00:00'},
#   {'dt': 1710482400,
#    'main': {'temp': 9.43,
#     'feels_like': 7.78,
#     'temp_min': 9.43,
#     'temp_max': 9.43,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.08, 'deg': 189, 'gust': 9.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-15 06:00:00'},
#   {'dt': 1710493200,
#    'main': {'temp': 12.99,
#     'feels_like': 12.2,
#     'temp_min': 12.99,
#     'temp_max': 12.99,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.11, 'deg': 211, 'gust': 7.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-15 09:00:00'},
#   {'dt': 1710504000,
#    'main': {'temp': 16.23,
#     'feels_like': 15.4,
#     'temp_min': 16.23,
#     'temp_max': 16.23,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.42, 'deg': 224, 'gust': 6.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-15 12:00:00'},
#   {'dt': 1710514800,
#    'main': {'temp': 16.45,
#     'feels_like': 15.72,
#     'temp_min': 16.45,
#     'temp_max': 16.45,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.69, 'deg': 230, 'gust': 6.06},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.52},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-15 15:00:00'},
#   {'dt': 1710525600,
#    'main': {'temp': 13.22,
#     'feels_like': 12.61,
#     'temp_min': 13.22,
#     'temp_max': 13.22,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.04, 'deg': 264, 'gust': 8.48},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.03},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-15 18:00:00'},
#   {'dt': 1710536400,
#    'main': {'temp': 11.78,
#     'feels_like': 11.23,
#     'temp_min': 11.78,
#     'temp_max': 11.78,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.24, 'deg': 238, 'gust': 9.07},
#    'visibility': 10000,
#    'pop': 0.51,
#    'rain': {'3h': 0.55},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-15 21:00:00'},
#   {'dt': 1710547200,
#    'main': {'temp': 10.77,
#     'feels_like': 10.25,
#     'temp_min': 10.77,
#     'temp_max': 10.77,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.35, 'deg': 233, 'gust': 10.04},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-16 00:00:00'},
#   {'dt': 1710558000,
#    'main': {'temp': 9.39,
#     'feels_like': 7.79,
#     'temp_min': 9.39,
#     'temp_max': 9.39,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 2.98, 'deg': 224, 'gust': 8.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-16 03:00:00'},
#   {'dt': 1710568800,
#    'main': {'temp': 8.59,
#     'feels_like': 6.72,
#     'temp_min': 8.59,
#     'temp_max': 8.59,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1006,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.16, 'deg': 207, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-16 06:00:00'},
#   {'dt': 1710579600,
#    'main': {'temp': 12.52,
#     'feels_like': 11.79,
#     'temp_min': 12.52,
#     'temp_max': 12.52,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 4.27, 'deg': 220, 'gust': 6.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-16 09:00:00'},
#   {'dt': 1710590400,
#    'main': {'temp': 12.71,
#     'feels_like': 11.94,
#     'temp_min': 12.71,
#     'temp_max': 12.71,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 5.47, 'deg': 246, 'gust': 8.05},
#    'visibility': 10000,
#    'pop': 0.36,
#    'rain': {'3h': 0.6},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-16 12:00:00'},
#   {'dt': 1710601200,
#    'main': {'temp': 12.36,
#     'feels_like': 11.56,
#     'temp_min': 12.36,
#     'temp_max': 12.36,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.63, 'deg': 264, 'gust': 8.86},
#    'visibility': 10000,
#    'pop': 0.76,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-16 15:00:00'},
#   {'dt': 1710612000,
#    'main': {'temp': 11.02,
#     'feels_like': 10.29,
#     'temp_min': 11.02,
#     'temp_max': 11.02,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.41, 'deg': 273, 'gust': 9.44},
#    'visibility': 10000,
#    'pop': 0.98,
#    'rain': {'3h': 0.45},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-16 18:00:00'},
#   {'dt': 1710622800,
#    'main': {'temp': 9.45,
#     'feels_like': 7.02,
#     'temp_min': 9.45,
#     'temp_max': 9.45,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 4.7, 'deg': 290, 'gust': 9.7},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-16 21:00:00'},
#   {'dt': 1710633600,
#    'main': {'temp': 6.03,
#     'feels_like': 2.98,
#     'temp_min': 6.03,
#     'temp_max': 6.03,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 4.27, 'deg': 294, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-17 00:00:00'},
#   {'dt': 1710644400,
#    'main': {'temp': 4.34,
#     'feels_like': 1.32,
#     'temp_min': 4.34,
#     'temp_max': 4.34,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1013,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.56, 'deg': 296, 'gust': 7.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-03-17 03:00:00'},
#   {'dt': 1710655200,
#    'main': {'temp': 3.21,
#     'feels_like': 1.05,
#     'temp_min': 3.21,
#     'temp_max': 3.21,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 2.22, 'deg': 321, 'gust': 4.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-17 06:00:00'},
#   {'dt': 1710666000,
#    'main': {'temp': 6.4,
#     'feels_like': 5.67,
#     'temp_min': 6.4,
#     'temp_max': 6.4,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.4, 'deg': 52, 'gust': 1.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-17 09:00:00'},
#   {'dt': 1710676800,
#    'main': {'temp': 9.19,
#     'feels_like': 7.98,
#     'temp_min': 9.19,
#     'temp_max': 9.19,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1013,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.34, 'deg': 115, 'gust': 2.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-03-17 12:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 3600,
#   'sunrise': 1710221230,
#   'sunset': 1710263104}}

# %% [markdown]
# # Exploring the json
# Remember, if you want to know more about any of the information in the json, or you're unsure what a key is, check out the [open weather docs](https://openweathermap.org/forecast5).
#
# First, let's look at the keys

# %%
json.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
json["cod"]
# Out:
# '200'

# %%
json["message"]
# Out:
# 0

# %%
json["cnt"]
# Out:
# 40

# %%
json["list"]

# %% [markdown]
# Looks like the information we'll want is in `list`. Let's look at the first element of `list` to investigate further.

# %%
json["list"][0]
# Out:
# {'dt': 1702641600,
#  'main': {'temp': 3.12,
#   'feels_like': -0.39,
#   'temp_min': 3.12,
#   'temp_max': 3.74,
#   'pressure': 1023,
#   'sea_level': 1023,
#   'grnd_level': 1025,
#   'humidity': 90,
#   'temp_kf': -0.62},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 55},
#  'wind': {'speed': 3.91, 'deg': 238, 'gust': 9.57},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2023-12-15 12:00:00'}

# %%
json["city"]
# Out:
# {'id': 2950159,
#  'name': 'Berlin',
#  'coord': {'lat': 52.5244, 'lon': 13.4105},
#  'country': 'DE',
#  'population': 1000000,
#  'timezone': 3600,
#  'sunrise': 1702624234,
#  'sunset': 1702651928}

# %% [markdown]
# # Building a DataFrame

# %% [markdown]
# ## What would we like from the json?
# Let's begin by exploring the first 2 items of `list` and see what we have.

# %%
json["list"][0]
# Out:
# {'dt': 1702641600,
#  'main': {'temp': 3.12,
#   'feels_like': -0.39,
#   'temp_min': 3.12,
#   'temp_max': 3.74,
#   'pressure': 1023,
#   'sea_level': 1023,
#   'grnd_level': 1025,
#   'humidity': 90,
#   'temp_kf': -0.62},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 55},
#  'wind': {'speed': 3.91, 'deg': 238, 'gust': 9.57},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2023-12-15 12:00:00'}

# %%
json["list"][1]
# Out:
# {'dt': 1702652400,
#  'main': {'temp': 4.22,
#   'feels_like': 0.9,
#   'temp_min': 4.22,
#   'temp_max': 4.93,
#   'pressure': 1028,
#   'sea_level': 1028,
#   'grnd_level': 1026,
#   'humidity': 91,
#   'temp_kf': -0.71},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'clouds': {'all': 79},
#  'wind': {'speed': 4, 'deg': 259, 'gust': 9.28},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'n'},
#  'dt_txt': '2023-12-15 15:00:00'}

# %% [markdown]
# When deciding what is useful, remember the project goals.
#
# The time the forecast is for will be useful.

# %%
json["list"][0]["dt_txt"]
# Out:
# '2023-12-15 12:00:00'

# %% [markdown]
# The temperature will be useful. Scooters don't have heaters!

# %%
json["list"][0]["main"]["temp"]
# Out:
# 3.12

# %% [markdown]
# The forecast will be useful. Scooters don't have a roof!

# %%
json["list"][0]["weather"][0]["main"]
# Out:
# 'Clouds'

# %% [markdown]
# If it's been recently raining will be useful. Wet conditions will affect scooter rentals.

# %%
json["list"][0]["rain"]["3h"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-7bf1b96bfefc> in <cell line: 1>()
# ----> 1 json["list"][0]["rain"]["3h"]
#
# KeyError: 'rain'

# %% [markdown]
# > If you get an error on 'rain', it's because it hasn't rained in the last 3 hours. But we know this key exists, because, like good Data Scientists, we read the [docs](https://openweathermap.org/forecast5)

# %% [markdown]
# Wind speed will be useful. It's likely to affect whether people rent scooters or not.

# %%
json["list"][0]["wind"]["speed"]
# Out:
# 3.91

# %% [markdown]
# ## Bringing together our chosen items

# %%
weather_items = []

for item in json["list"]:
    weather_item = {
        "forecast_time": item.get("dt_txt", None),
        "temperature": item["main"].get("temp", None),
        "forecast": item["weather"][0].get("main", None),
        "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
        "wind_speed": item["wind"].get("speed", None),
    }

    weather_items.append(weather_item)

weather_df = pd.DataFrame(weather_items)

weather_df.head()
# Out:
#          forecast_time  temperature forecast  rain_in_last_3h  wind_speed
# 0  2024-03-12 15:00:00        14.79    Clear              0.0        3.23
# 1  2024-03-12 18:00:00        13.33   Clouds              0.0        2.54
# 2  2024-03-12 21:00:00        11.00   Clouds              0.0        2.81
# 3  2024-03-13 00:00:00         7.92   Clouds              0.0        2.38
# 4  2024-03-13 03:00:00         6.15   Clouds              0.0        2.08

# %% [markdown]
# The `rain` key in the JSON data is not always present. In the absence of this key, it's assumed that there hasn't been any recent rainfall. Since this key isn't always available, not encountering it during our loop can cause an error. To address this, we'll employ two `.get()` methods to handle the absence of the `rain` key.
#
# > **Remember:** The second parameter of `.get()` serves as a fallback value, which is inserted into our dictionary if the key we're looking for doesn't exist.
#
# The first `.get()` method checks for the existence of the `rain` key. If present, it will use the value associated with that key. If the `rain` key is missing, an empty dictionary will be used, preventing the code from breaking. The second `.get()` method checks for the `3h` key. If present, it will use its value. Otherwise, a default value of `0` will be used.

# %% [markdown]
# # Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime
from pytz import timezone

def get_weather_data(cities):
  # As we will be working in the cloud, computers can be located anywhere
  # Let's correct the computer timezone to our local timezone
  berlin_timezone = timezone('Europe/Berlin')
  API_key = userdata.get('openWeatherApi')
  weather_items = []

  for city in cities:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
    response = requests.get(url)
    json = response.json()

    # Added the time retrieved so we know when the forecast was made
    retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

    for item in json["list"]:
        weather_item = {
            # Added the city name, so the information is clear when looking at multiple cities
            "city": city,
            "forecast_time": item.get("dt_txt", None),
            "temperature": item["main"].get("temp", None),
            "forecast": item["weather"][0].get("main", None),
            "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
            "wind_speed": item["wind"].get("speed", None),
            "data_retrieved_at": retrieval_time
        }

        weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)

  return weather_df

# %%
get_weather_data(["Berlin", "Hamburg", "Munich"])
# Out:
#        city        forecast_time  temperature forecast  rain_in_last_3h  \
# 0    Berlin  2023-12-15 12:00:00         3.12   Clouds             0.00
# 1    Berlin  2023-12-15 15:00:00         4.22   Clouds             0.00
# 2    Berlin  2023-12-15 18:00:00         4.21   Clouds             0.00
# 3    Berlin  2023-12-15 21:00:00         3.71   Clouds             0.00
# 4    Berlin  2023-12-16 00:00:00         3.59   Clouds             0.00
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2023-12-19 21:00:00         2.16    Clear             0.00
# 116  Munich  2023-12-20 00:00:00         1.82    Clear             0.00
# 117  Munich  2023-12-20 03:00:00         2.43   Clouds             0.00
# 118  Munich  2023-12-20 06:00:00         3.36     Rain             0.66
# 119  Munich  2023-12-20 09:00:00         4.05     Rain             2.00
#
#      wind_speed    data_retrieved_at
# 0          3.91  2023-12-15 11:08:14
# 1          4.00  2023-12-15 11:08:14
# 2          3.67  2023-12-15 11:08:14
# 3          3.42  2023-12-15 11:08:14
# 4          3.92  2023-12-15 11:08:14
# ..          ...                  ...
# 115        3.10  2023-12-15 11:08:15
# 116        4.37  2023-12-15 11:08:15
# 117        5.84  2023-12-15 11:08:15
# 118        6.59  2023-12-15 11:08:15
# 119        6.22  2023-12-15 11:08:15
#
# [120 rows x 7 columns]

# %% [markdown]
# # Making our function work with our SQL cities data
# This section delves into a more advanced aspect of the project, which may be beyond the point many of you got to. However, it serves as an illustrative example of how to structure your work effectively. It demonstrates how we can compartmentalise various aspects of our data processing pipeline into distinct functions, enhancing code readability and facilitating debugging. It's a good idea to start writing your pipeline in a similar manner ready for the cloud.
# > This part will only work locally, not on colab. You must also create your weather table in SQL first.

# %%
import pandas as pd
import requests
from pytz import timezone
from datetime import datetime

def retreiving_and_sending_data():
  connection_string = connection()
  cities_df = get_cities_data(connection_string)
  weather_df = get_weather_data(cities_df)
  send_weather_data(weather_df, connection_string)
  return "Data has been updated"

def connection():
  schema = "gans"
  host = "127.0.0.1"
  user = "root"
  password = "YOUR_PASSWORD_HERE"
  port = 3306
  return f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

def get_cities_data(connection_string):
  return pd.read_sql("cities", con=connection_string)

def get_weather_data(cities_df):
  berlin_timezone = timezone('Europe/Berlin')
  API_key = 'YOUR_API_HERE'
  weather_items = []

  for city in cities_df["city"]:
    url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
    response = requests.get(url)
    json = response.json()

    # As we are now using the data from our relational database
    # the city should reflect the city_id and not the city name
    city_id = cities_df.loc[cities_df["city"] == city, "city_id"].values[0]

    retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

    for item in json["list"]:
        weather_item = {
            "city_id": city_id,
            "forecast_time": item.get("dt_txt", None),
            "temperature": item["main"].get("temp", None),
            "forecast": item["weather"][0].get("main", None),
            "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
            "wind_speed": item["wind"].get("speed", None),
            "data_retrieved_at": retrieval_time
        }

        weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)
  weather_df["forecast_time"] = pd.to_datetime(weather_df["forecast_time"])
  weather_df["data_retrieved_at"] = pd.to_datetime(weather_df["data_retrieved_at"])

  return weather_df

def send_weather_data(weather_df, connection_string):
  weather_df.to_sql('weather',
                    if_exists='append',
                    con=connection_string,
                    index=False)

# %%
city_ids = [1, 2, 3]
city_names = ["Berlin", "Frankfurt", "Munich"]

cities_df = pd.DataFrame({"city_id": city_ids,
                          "city_name": city_names})

cities_df
# Out:
#    city_id  city_name
# 0        1     Berlin
# 1        2  Frankfurt
# 2        3     Munich

# %%
cities_df.loc[cities_df["city_name"] == "Munich", "city_id"].values[0]
# Out:
# 3

# %%
retreiving_and_sending_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-ed54ffb11db9> in <cell line: 1>()
# ----> 1 sending_and_retreiving_data()
#
# <ipython-input-32-9d4fe272c76f> in sending_and_retreiving_data()
#       6 def sending_and_retreiving_data():
#       7   connection_string = connection()
# ----> 8   cities_df = get_cities_data(connection_string)
#       9   weather_df = get_weather_data(cities_df)
#      10   send_weather_data(weather_df, connection_string)
#
# <ipython-input-32-9d4fe272c76f> in get_cities_data(connection_string)
#      20
#      21 def get_cities_data(connection_string):
# ---> 22   return pd.read_sql("cities", con=connection_string)
#      23
#      24 def get_weather_data(cities_df):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     559     1           1  2010-11-12
#     560     """
# --> 561     pandas_sql = pandasSQL_builder(con)
#     562
#     563     if isinstance(pandas_sql, SQLiteDatabase):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in pandasSQL_builder(con, schema)
#     752             raise ImportError("Using URI string without sqlalchemy installed.")
#     753         else:
# --> 754             con = sqlalchemy.create_engine(con)
#     755
#     756     if sqlalchemy is not None and isinstance(con, sqlalchemy.engine.Connectable):
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     599             if k in kwargs:
#     600                 dbapi_args[k] = pop_kwarg(k)
# --> 601         dbapi = dbapi_meth(**dbapi_args)
#     602
#     603     dialect_args["dbapi"] = dbapi
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/dialects/mysql/pymysql.py in import_dbapi(cls)
#      73     @classmethod
#      74     def import_dbapi(cls):
# ---> 75         return __import__("pymysql")
#      76
#      77     @langhelpers.memoized_property
#
# ModuleNotFoundError: No module named 'pymysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
